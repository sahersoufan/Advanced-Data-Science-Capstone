# %% [markdown]
# # **Dubai Estates Price Prediction**
# <p>in this project we will predict the price of <strong>Dubai</strong> estates based on studing the <strong>2022</strong> transactions.</p>
#
# ## ETL (Extract, Transform, Load)
#
# We collect the data from **the Dubai Government Land Department westie**.
# - relational data.
# - One table.
# - csv File.
#
#
# <a href='https://dubailand.gov.ae/en/'>Dubai Government Land Department webstie Link</a>

# %%
import pandas as pd

# %% [markdown]
# this data from the data wrangling step in the **Initial Data Exploration**, it's clean.

# %%
df = pd.read_csv('data/transactions-2022-12-23.csv')
df.head()
# Out:
#   Transaction Number     Transaction Date  Property ID Transaction Type  \
# 0         102-1-2022  2022-01-03 07:30:34   1131371499            Sales
# 1        102-10-2022  2022-01-03 07:32:56    100227279            Sales
# 2       102-100-2022  2022-01-03 12:30:23   1147007457            Sales
# 3      102-1000-2022  2022-01-10 13:21:58   1133339823            Sales
# 4     102-10000-2022  2022-04-13 11:21:32   1171598130            Sales
#
#       Transaction sub type Registration type Is Free Hold?        Usage  \
# 0  Sell - Pre registration          Off-Plan     Free Hold  Residential
# 1  Sell - Pre registration          Off-Plan     Free Hold  Residential
# 2  Sell - Pre registration          Off-Plan     Free Hold  Residential
# 3  Sell - Pre registration          Off-Plan     Free Hold  Residential
# 4  Sell - Pre registration          Off-Plan     Free Hold  Residential
#
#              Area Property Type  ... Property Size (sq.m)  Room(s)  Parking  \
# ...

# %% [markdown]
# We will keep the data as csv file in local,the data consist of 23 columns with more than 100000 samples, One Relational Table, there is no transformation to do on it, we tried to upload it to the **IBM Cloud** and work in ibm watson but there is some technical issues, so we will complete the work in the next stages localy.
